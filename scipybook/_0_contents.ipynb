# %% [markdown]
# # Pythonで科学計算
# ## NumPy
#   * ## **[NumPyの配列](./numpy-ndarray-jp.ipynb#NumPyの配列)**
#     * [リストとarray配列のメモリ構造](./numpy-ndarray-jp.ipynb#リストとarray配列のメモリ構造)
#     * [NumPy配列のメモリ構造](./numpy-ndarray-jp.ipynb#NumPy配列のメモリ構造)
#     * [shapeとstrides属性](./numpy-ndarray-jp.ipynb#shapeとstrides属性)
#     * [メモリビュー](./numpy-ndarray-jp.ipynb#メモリビュー)
#     * [配列の作成](./numpy-ndarray-jp.ipynb#配列の作成)
#       * [1次元配列のインデックスアクセス](./numpy-ndarray-jp.ipynb#1次元配列のインデックスアクセス)
#       * [多次元配列のインデックスアクセス](./numpy-ndarray-jp.ipynb#多次元配列のインデックスアクセス)
#   * ## **[ブロードキャストとufunc関数](./numpy-ufunc-jp.ipynb#ブロードキャストとufunc関数)**
#     * [四則演算](./numpy-ufunc-jp.ipynb#四則演算)
#     * [比較演算と論理演算](./numpy-ufunc-jp.ipynb#比較演算と論理演算)
#     * [ブロードキャスト](./numpy-ufunc-jp.ipynb#ブロードキャスト)
#     * [ufuncのメソッド](./numpy-ufunc-jp.ipynb#ufuncのメソッド)
#   * ## **[配列のインデックスアクセス](./numpy-index-jp.ipynb#配列のインデックスアクセス)**
#     * [インデックスオブジェクト](./numpy-index-jp.ipynb#インデックスオブジェクト)
#     * [整数配列をインデックスとして使用](./numpy-index-jp.ipynb#整数配列をインデックスとして使用)
#     * [複雑な例](./numpy-index-jp.ipynb#複雑な例)
#     * [ブール配列をインデックスとして使用](./numpy-index-jp.ipynb#ブール配列をインデックスとして使用)
#   * ## **[NumPyの関数群](./numpy-functions-jp.ipynb#NumPyの関数群)**
#     * [乱数](./numpy-functions-jp.ipynb#乱数)
#     * [合計、平均、分散](./numpy-functions-jp.ipynb#合計平均分散)
#     * [ソートと大きさ](./numpy-functions-jp.ipynb#ソートと大きさ)
#     * [統計関数](./numpy-functions-jp.ipynb#統計関数)
#     * [区分関数](./numpy-functions-jp.ipynb#区分関数)
#     * [多次元配列の操作](./numpy-functions-jp.ipynb#多次元配列の操作)
#     * [多項式関数](./numpy-functions-jp.ipynb#多項式関数)
#       * [多項式関数クラス](./numpy-functions-jp.ipynb#多項式関数クラス)
#     * [各種の積演算](./numpy-functions-jp.ipynb#各種の積演算)
#     * [汎用ufunc関数](./numpy-functions-jp.ipynb#汎用ufunc関数)
# ## SciPy
#   * ## **[フィッティングと最適化-optimize](./scipy-optimize-jp.ipynb#フィッティングと最適化-optimize)**
#     * [非線形方程式の求解](./scipy-optimize-jp.ipynb#非線形方程式の求解)
#     * [最小二乗フィッティング](./scipy-optimize-jp.ipynb#最小二乗フィッティング)
#     * [異常値の影響を軽減する](./scipy-optimize-jp.ipynb#異常値の影響を軽減する)
#     * [関数の局所最小値の計算](./scipy-optimize-jp.ipynb#関数の局所最小値の計算)
#     * [全域最小値の計算](./scipy-optimize-jp.ipynb#全域最小値の計算)
#     * [応用実例](./scipy-optimize-jp.ipynb#応用実例)
#       * [区分関数のフィッティング](./scipy-optimize-jp.ipynb#区分関数のフィッティング)
#       * [エネルギー最小値による懸垂線の計算](./scipy-optimize-jp.ipynb#エネルギー最小値による懸垂線の計算)
#       * [最速降線の計算](./scipy-optimize-jp.ipynb#最速降線の計算)
#   * ## **[線形代数-linalg](./scipy-linalg-jp.ipynb#線形代数-linalg)**
#     * [線形方程式の解法](./scipy-linalg-jp.ipynb#線形方程式の解法)
#     * [最小二乗解](./scipy-linalg-jp.ipynb#最小二乗解)
#     * [固有値と固有ベクトル](./scipy-linalg-jp.ipynb#固有値と固有ベクトル)
#     * [特異値分解-SVD](./scipy-linalg-jp.ipynb#特異値分解-SVD)
#   * ## **[統計-stats](./scipy-stats-jp.ipynb#統計-stats)**
#     * [連続確率分布](./scipy-stats-jp.ipynb#連続確率分布)
#     * [離散確率分布](./scipy-stats-jp.ipynb#離散確率分布)
#     * [カーネル密度推定](./scipy-stats-jp.ipynb#カーネル密度推定)
#     * [二項分布、ポアソン分布、ガンマ分布](./scipy-stats-jp.ipynb#二項分布ポアソン分布ガンマ分布)
#     * [スチューデントのt分布とt検定](./scipy-stats-jp.ipynb#スチューデントのt分布とt検定)
#     * [カイ二乗分布とカイ二乗検定](./scipy-stats-jp.ipynb#カイ二乗分布とカイ二乗検定)
#   * ## **[数値積分-integrate](./scipy-integrate-jp.ipynb#数値積分-integrate)**
#     * [球の体積](./scipy-integrate-jp.ipynb#球の体積)
#     * [常微分方程式の解法](./scipy-integrate-jp.ipynb#常微分方程式の解法)
#     * [質量-ばね-ダンパーシステム](./scipy-integrate-jp.ipynb#質量-ばね-ダンパーシステム)
#     * [懸垂線のシミュレーション](./scipy-integrate-jp.ipynb#懸垂線のシミュレーション)
#       * [懸垂線の境界値問題](./scipy-integrate-jp.ipynb#懸垂線の境界値問題)
#   * ## **[信号処理-signal](./scipy-signal-jp.ipynb#信号処理-signal)**
#     * [メディアンフィルタ](./scipy-signal-jp.ipynb#メディアンフィルタ)
#     * [フィルタ設計](./scipy-signal-jp.ipynb#フィルタ設計)
#     * [連続時間線形システム](./scipy-signal-jp.ipynb#連続時間線形システム)
#   * ## **[補間-interpolate](./scipy-interpolate-jp.ipynb#補間-interpolate)**
#     * [一次元補間](./scipy-interpolate-jp.ipynb#一次元補間)
#       * [外挿とスプライン補間](./scipy-interpolate-jp.ipynb#外挿とスプライン補間)
#       * [パラメトリック補間](./scipy-interpolate-jp.ipynb#パラメトリック補間)
#       * [単調補間](./scipy-interpolate-jp.ipynb#単調補間)
#     * [多次元補間](./scipy-interpolate-jp.ipynb#多次元補間)
#       * [griddata](./scipy-interpolate-jp.ipynb#griddata)
#       * [放射基底関数補間](./scipy-interpolate-jp.ipynb#放射基底関数補間)
#   * ## **[疎行列-sparse](./scipy-sparse-jp.ipynb#疎行列-sparse)**
#     * [疎行列の保存形式](./scipy-sparse-jp.ipynb#疎行列の保存形式)
#     * [大規模な線形方程式の解法](./scipy-sparse-jp.ipynb#大規模な線形方程式の解法)
#     * [最短経路](./scipy-sparse-jp.ipynb#最短経路)
#   * ## **[画像処理-ndimage](./scipy-ndimage-jp.ipynb#画像処理-ndimage)**
#     * [形態学的画像処理](./scipy-ndimage-jp.ipynb#形態学的画像処理)
#       * [膨張と収縮](./scipy-ndimage-jp.ipynb#膨張と収縮)
#       * [HitとMiss](./scipy-ndimage-jp.ipynb#HitとMiss)
#     * [画像分割](./scipy-ndimage-jp.ipynb#画像分割)
#   * ## **[空間アルゴリズム-spatial](./scipy-spatial-jp.ipynb#空間アルゴリズム-spatial)**
#     * [最近傍点の計算](./scipy-spatial-jp.ipynb#最近傍点の計算)
#     * [凸包](./scipy-spatial-jp.ipynb#凸包)
#     * [ボロノイ図](./scipy-spatial-jp.ipynb#ボロノイ図)
#     * [ドロネー三角形分割](./scipy-spatial-jp.ipynb#ドロネー三角形分割)
# ## SymPy
#   * ## **[SymPyで記号演算](./sympy-intro-jp.ipynb#SymPyで記号演算)**
#     * [例から始める](./sympy-intro-jp.ipynb#例から始める)
#       * [表紙の古典的な公式](./sympy-intro-jp.ipynb#表紙の古典的な公式)
#       * [球体の体積](./sympy-intro-jp.ipynb#球体の体積)
#       * [数値微分](./sympy-intro-jp.ipynb#数値微分)
#     * [数学式](./sympy-intro-jp.ipynb#数学式)
#       * [シンボル](./sympy-intro-jp.ipynb#シンボル)
#       * [数値](./sympy-intro-jp.ipynb#数値)
#       * [演算子と関数](./sympy-intro-jp.ipynb#演算子と関数)
#       * [ワイルドカード](./sympy-intro-jp.ipynb#ワイルドカード)
#     * [記号計算](./sympy-intro-jp.ipynb#記号計算)
#       * [式の変換と簡略化](./sympy-intro-jp.ipynb#式の変換と簡略化)
#       * [方程式](./sympy-intro-jp.ipynb#方程式)
#       * [微分](./sympy-intro-jp.ipynb#微分)
#       * [微分方程式](./sympy-intro-jp.ipynb#微分方程式)
#       * [積分](./sympy-intro-jp.ipynb#積分)
#     * [SymPyで自動コード生成](./sympy-output-jp.ipynb#SymPyで自動コード生成)
#     * [`lambdify`で式から関数に変換](./sympy-output-jp.ipynb#lambdifyで式から関数に変換)
#     * [Splineのコード生成](./sympy-output-jp.ipynb#Splineのコード生成)
#     * [`autowrap()`で式のコンパイル](./sympy-output-jp.ipynb#autowrapで式のコンパイル)
#     * [codegenでソースコード作成](./sympy-output-jp.ipynb#codegenでソースコード作成)
# ## 高速化
#   * ## **[プログラムの実行効率向上](./fastcode-intro-jp.ipynb#プログラムの実行効率向上)**
#     * [Pythonの計算が遅い理由](./fastcode-intro-jp.ipynb#Pythonの計算が遅い理由)
#       * [Pythonオブジェクト](./fastcode-intro-jp.ipynb#Pythonオブジェクト)
#       * [Pythonインタプリタ](./fastcode-intro-jp.ipynb#Pythonインタプリタ)
#     * [C言語コンパイラの設定](./fastcode-intro-jp.ipynb#C言語コンパイラの設定)
#     * [Julia集合の計算最適化](./fastcode-intro-jp.ipynb#Julia集合の計算最適化)
#       * [C言語関数の呼び出し](./fastcode-intro-jp.ipynb#C言語関数の呼び出し)
#       * [Cythonで計算速度向上](./fastcode-intro-jp.ipynb#Cythonで計算速度向上)
#       * [NumbaでJITコンパイル](./fastcode-intro-jp.ipynb#NumbaでJITコンパイル)
#       * [反復アルゴリズムの改良](./fastcode-intro-jp.ipynb#反復アルゴリズムの改良)
#   * ## **[CFFIで外部関数を呼び出す](./cffi-intro-jp.ipynb#CFFIで外部関数を呼び出す)**
#     * [2つの呼び出しモード](./cffi-intro-jp.ipynb#2つの呼び出しモード)
#       * [ABIモード](./cffi-intro-jp.ipynb#ABIモード)
#       * [APIモード](./cffi-intro-jp.ipynb#APIモード)
#       * [cffiマジックコマンド](./cffi-intro-jp.ipynb#cffiマジックコマンド)
#     * [C言語のデータ型](./cffi-intro-jp.ipynb#C言語のデータ型)
#       * [配列とポインタ](./cffi-intro-jp.ipynb#配列とポインタ)
#       * [文字列とバイト列](./cffi-intro-jp.ipynb#文字列とバイト列)
#       * [構造体](./cffi-intro-jp.ipynb#構造体)
#     * [CFFIのメモリ管理](./cffi-intro-jp.ipynb#CFFIのメモリ管理)
#     * [9軸センサー融合アルゴリズム](./cffi-intro-jp.ipynb#9軸センサー融合アルゴリズム)
#       * [ABIモード](./cffi-intro-jp.ipynb#ABIモード)
#       * [APIモード](./cffi-intro-jp.ipynb#APIモード)
#       * [データの可視化](./cffi-intro-jp.ipynb#データの可視化)
#   * ## **[Cythonで高速化](./cython-intro-jp.ipynb#Cythonで高速化)**
#     * [ベクトル集合の距離行列の計算](./cython-intro-jp.ipynb#ベクトル集合の距離行列の計算)
#       * [%%cythonマジックコマンド](./cython-intro-jp.ipynb#cythonマジックコマンド)
#       * [Cythonで拡張モジュール作成](./cython-intro-jp.ipynb#Cythonで拡張モジュール作成)
#     * [Cythonの基本文法](./cython-intro-jp.ipynb#Cythonの基本文法)
#       * [C言語でのPythonオブジェクト型](./cython-intro-jp.ipynb#C言語でのPythonオブジェクト型)
#       * [`cdef` を用いた変数型の宣言](./cython-intro-jp.ipynb#cdef-を用いた変数型の宣言)
#       * [`def` を用いた関数定義](./cython-intro-jp.ipynb#def-を用いた関数定義)
#       * [`cdef` を用いたC関数定義](./cython-intro-jp.ipynb#cdef-を用いたC関数定義)
#     * [配列の効率的な処理](./cython-intro-jp.ipynb#配列の効率的な処理)
#       * [Cythonのメモリビュー](./cython-intro-jp.ipynb#Cythonのメモリビュー)
#       * [NumPy配列とメモリビュー](./cython-intro-jp.ipynb#NumPy配列とメモリビュー)
#     * [PythonのオブジェクトとAPI](./cython-intro-jp.ipynb#PythonのオブジェクトとAPI)
#       * [`list`オブジェクトの操作](./cython-intro-jp.ipynb#listオブジェクトの操作)
#       * [`tuple`オブジェクトの作成](./cython-intro-jp.ipynb#tupleオブジェクトの作成)
#       * [`array.array`を動的配列として使用](./cython-intro-jp.ipynb#arrayarrayを動的配列として使用)
#   * ## **[Cythonの応用技法](./cython-advanced-jp.ipynb#Cythonの応用技法)**
#     * [拡張型](./cython-advanced-jp.ipynb#拡張型)
#       * [拡張型の基本構造](./cython-advanced-jp.ipynb#拡張型の基本構造)
#       * [1次元浮動小数点ベクトル型](./cython-advanced-jp.ipynb#1次元浮動小数点ベクトル型)
#       * [multifastライブラリのラッピング](./cython-advanced-jp.ipynb#multifastライブラリのラッピング)
#     * [Cythonのテクニック集](./cython-advanced-jp.ipynb#Cythonのテクニック集)
#       * [ufunc 関数の作成](./cython-advanced-jp.ipynb#ufunc-関数の作成)
#       * [DLL内の関数の高速呼び出し](./cython-advanced-jp.ipynb#DLL内の関数の高速呼び出し)
#       * [BLAS関数の呼び出し](./cython-advanced-jp.ipynb#BLAS関数の呼び出し)
#         * [`saxpy()`関数のラッピング](./cython-advanced-jp.ipynb#saxpy関数のラッピング)
#         * [`dgemm()`高速行列積](./cython-advanced-jp.ipynb#dgemm高速行列積)
#   * ## **[JITコンパイラ-Numba](./numba-intro-jp.ipynb#JITコンパイラ-Numba)**
#     * [データ型](./numba-intro-jp.ipynb#データ型)
#       * [関数シグネチャ](./numba-intro-jp.ipynb#関数シグネチャ)
#       * [配列型](./numba-intro-jp.ipynb#配列型)
#       * [構造体型](./numba-intro-jp.ipynb#構造体型)
#       * [関数を引数として](./numba-intro-jp.ipynb#関数を引数として)
#       * [局所変数の型](./numba-intro-jp.ipynb#局所変数の型)
#       * [コンテナ型](./numba-intro-jp.ipynb#コンテナ型)
#     * [NumPy配列演算](./numba-intro-jp.ipynb#NumPy配列演算)
#       * [ブロードキャスト演算の最適化](./numba-intro-jp.ipynb#ブロードキャスト演算の最適化)
#       * [配列のイテレーション](./numba-intro-jp.ipynb#配列のイテレーション)
#     * [`vectorize`でufunc関数を作成](./numba-intro-jp.ipynb#vectorizeでufunc関数を作成)
#     * [ステンシルカーネルの作成](./numba-intro-jp.ipynb#ステンシルカーネルの作成)
#       * [水波のシミュレーション](./numba-intro-jp.ipynb#水波のシミュレーション)
# ## 可視化
#   * ## **[matplotlibの基本](./matplotlib-intro-jp.ipynb#matplotlibの基本)**
#     * [描画の基本](./matplotlib-intro-jp.ipynb#描画の基本)
#       * [pyplotモジュールを使用した描画](./matplotlib-intro-jp.ipynb#pyplotモジュールを使用した描画)
#       * [オブジェクト指向方式での描画](./matplotlib-intro-jp.ipynb#オブジェクト指向方式での描画)
#       * [属性の設定](./matplotlib-intro-jp.ipynb#属性の設定)
#       * [複数のサブプロットの描画](./matplotlib-intro-jp.ipynb#複数のサブプロットの描画)
#       * [設定ファイル](./matplotlib-intro-jp.ipynb#設定ファイル)
#       * [グラフに日本語を表示する](./matplotlib-intro-jp.ipynb#グラフに日本語を表示する)
#     * [Artistオブジェクト](./matplotlib-intro-jp.ipynb#Artistオブジェクト)
#       * [Artistの属性](./matplotlib-intro-jp.ipynb#Artistの属性)
#       * [Figureコンテナ](./matplotlib-intro-jp.ipynb#Figureコンテナ)
#       * [Axesコンテナ](./matplotlib-intro-jp.ipynb#Axesコンテナ)
#       * [Axisコンテナ](./matplotlib-intro-jp.ipynb#Axisコンテナ)
#       * [Artistオブジェクトの関係](./matplotlib-intro-jp.ipynb#Artistオブジェクトの関係)
#   * ## **[matplotlibの描画関数](./matplotlib-plots-jp.ipynb#matplotlibの描画関数)**
#     * [対数座標グラフ](./matplotlib-plots-jp.ipynb#対数座標グラフ)
#     * [極座標グラフ](./matplotlib-plots-jp.ipynb#極座標グラフ)
#     * [棒グラフ](./matplotlib-plots-jp.ipynb#棒グラフ)
#     * [散布図](./matplotlib-plots-jp.ipynb#散布図)
#     * [画像](./matplotlib-plots-jp.ipynb#画像)
#     * [等高線図](./matplotlib-plots-jp.ipynb#等高線図)
#     * [四角形メッシュ](./matplotlib-plots-jp.ipynb#四角形メッシュ)
#     * [三角形メッシュ](./matplotlib-plots-jp.ipynb#三角形メッシュ)
#     * [矢印図](./matplotlib-plots-jp.ipynb#矢印図)
#     * [3次元グラフ](./matplotlib-plots-jp.ipynb#3次元グラフ)
#   * ## **[matplotlibの高級用法](./matplotlib-advanced-jp.ipynb#matplotlibの高級用法)**
#     * [座標変換と注釈](./matplotlib-advanced-jp.ipynb#座標変換と注釈)
#       * [四つの座標系](./matplotlib-advanced-jp.ipynb#四つの座標系)
#       * [座標変換のパイプライン](./matplotlib-advanced-jp.ipynb#座標変換のパイプライン)
#       * [シャドウ効果の作成](./matplotlib-advanced-jp.ipynb#シャドウ効果の作成)
#       * [注釈の追加](./matplotlib-advanced-jp.ipynb#注釈の追加)
#     * [テクニック集](./matplotlib-advanced-jp.ipynb#テクニック集)
#       * [aggバックエンドて描画する](./matplotlib-advanced-jp.ipynb#aggバックエンドて描画する)
#       * [アニメーション](./matplotlib-advanced-jp.ipynb#アニメーション)
#         * [キャッシュで高速に再描画](./matplotlib-advanced-jp.ipynb#キャッシュで高速に再描画)
#         * [animationモジュール](./matplotlib-advanced-jp.ipynb#animationモジュール)
#   * ## **[Bokehの基本](./bokeh-intro-jp.ipynb#Bokehの基本)**
#     * [チャートの表示方法](./bokeh-intro-jp.ipynb#チャートの表示方法)
#       * [Notebook内で表示](./bokeh-intro-jp.ipynb#Notebook内で表示)
#       * [Javascriptでチャートの更新](./bokeh-intro-jp.ipynb#Javascriptでチャートの更新)
#       * [Pythonでチャートの更新](./bokeh-intro-jp.ipynb#Pythonでチャートの更新)
#       * [Bokehサーバー](./bokeh-intro-jp.ipynb#Bokehサーバー)
#       * [Notebookにサーバーを埋め込む](./bokeh-intro-jp.ipynb#Notebookにサーバーを埋め込む)
#     * [Bokehのモデル](./bokeh-intro-jp.ipynb#Bokehのモデル)
#       * [Bokeh属性](./bokeh-intro-jp.ipynb#Bokeh属性)
#       * [モデルオブジェクトのクエリ](./bokeh-intro-jp.ipynb#モデルオブジェクトのクエリ)
#       * [コールバック関数](./bokeh-intro-jp.ipynb#コールバック関数)
#       * [ウィジェットオブジェクト](./bokeh-intro-jp.ipynb#ウィジェットオブジェクト)
#       * [レイアウトオブジェクト](./bokeh-intro-jp.ipynb#レイアウトオブジェクト)
#   * ## **[PanelでUIの作成](./panel-intro-jp.ipynb#PanelでUIの作成)**
#     * [UIの作成方法](./panel-intro-jp.ipynb#UIの作成方法)
#       * [`interact`](./panel-intro-jp.ipynb#interact)
#       * [コールバック型](./panel-intro-jp.ipynb#コールバック型)
#       * [`bind`型](./panel-intro-jp.ipynb#bind型)
#       * [`Parameterized`型](./panel-intro-jp.ipynb#Parameterized型)
#     * [フーリエ級数のUI](./panel-intro-jp.ipynb#フーリエ級数のUI)
#       * [リアクティブ型](./panel-intro-jp.ipynb#リアクティブ型)
#       * [コールバック型](./panel-intro-jp.ipynb#コールバック型)
#     * [Panelのクラス類](./panel-intro-jp.ipynb#Panelのクラス類)
#     * [Paramてパラメータを定義](./panel-intro-jp.ipynb#Paramてパラメータを定義)
#       * [Parameter属性](./panel-intro-jp.ipynb#Parameter属性)
#       * [コールバック関数](./panel-intro-jp.ipynb#コールバック関数)
#       * [自動生成UI](./panel-intro-jp.ipynb#自動生成UI)
#
#
# <div class="scipybook-contents">end</div>

# %%
# %%javascript
# var fix_links = function(){
# setTimeout(() => {
# console.log("run javascript: querySelectorAll");
# document.querySelectorAll('a[data-commandlinker-args]').forEach(link => {
#     try {
#         // Parse the JSON stored in data-commandlinker-args
#         let args = JSON.parse(link.getAttribute('data-commandlinker-args'));
#
#         if (args.id && args.id.startsWith("#")) {
#             // Decode the URL-encoded id
#             let decodedId = decodeURIComponent(args.id);
#
#             // Update the JSON data with the decoded id
#             args.id = decodedId;
#
#             // Set the updated JSON back to the attribute
#             link.setAttribute('data-commandlinker-args', JSON.stringify(args));
#         }
#     } catch (e) {
#         console.error("Error processing link:", link, e);
#     }
# })
# }, 1000);
# }
#
# function waitForElement(selector, callback) {
#     const observer = new MutationObserver((mutations, obs) => {
#         const element = document.querySelector(selector);
#         if (element) {
#             obs.disconnect(); // Stop observing after element appears
#             callback(element);
#         }
#     });
#
#     observer.observe(document.body, { childList: true, subtree: true });
# }
#
# // Example: Run function when `.scipybook-contents` appears
# waitForElement(".scipybook-contents", (element) => {
#     console.log("Element found:", element);
#     fix_links();
# });
